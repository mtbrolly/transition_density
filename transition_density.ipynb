# %% [markdown]
# # Visualising the transition density

# %% [markdown]
# This notebook allows the user to plot the transition density for a given initial position using a simple function.

# %%
from utils import plot_transition_density

# %% [markdown]
# Just enter an initial position in longitude-latitude coordinates.

# %%
plot_transition_density((-74.5, 34.85))

# %% [markdown]
# The equivalent Gaussian model can also be visualised by passing the optional keyword argument N_C=1.

# %%
plot_transition_density((-74.5, 34.85), N_C=1)

# %% [markdown]
# Here are another couple of examples.

# %%
plot_transition_density((-60., 42.))

# %%
plot_transition_density((-48., 39.))
